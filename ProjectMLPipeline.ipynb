# %% [markdown]
# <a href="https://colab.research.google.com/github/Emboiss13/DevicePositioningMLModel/blob/42-train-model-google-colab/ProjectMLPipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
# Out:
# <module 'torch.version' from '/usr/local/lib/python3.12/dist-packages/torch/version.py'>
